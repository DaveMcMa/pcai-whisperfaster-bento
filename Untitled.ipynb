# %%
import requests

FASTER_URL = "https://rundmc-whisper-faster-bento.project-public.serving.hpepcai4.demo.local"
FASTER_TOKEN = "eyJhbGciOiJSUzI1NiIsImtpZCI6Ikh2V3o0V1BoU3dkNFY4Tk9MSk9ObHM3Wk9UU1hxWjJLR0xyb1NwMldfSjQifQ.....eVWPkG3ZIGCdO6W27egvHo1O5_7KaL5mFXIcTddFMUAI9e4ZvOq_PjukMcwUA3ZFMaeJC0zzMIRZiYiukevmB6HrjkWsiwPNPWVI_afd2mL-cgDQh9c9HxwynGiBOeUNVyoygc_QnSCklmL84oP7vNp4EFv7DAGFlX4Agci6p1XqRcsJOpOeGnsWJYEwRsQJjyVYIVKOC_iaKgAmMozb1QYAdOBSM6o4fFfS7VDoxmKgCT7JcukGpCwS-PGY8XAko1fMs5ib4zsOfUfftKpY6rnxIv2sKGJvT3F1imuLWll4NQ0wNrDjAXt6PUotWEMfEY_1zO72EyjaRAxgYCuKtg"

with open("t1.wav", "rb") as f:
    r = requests.post(
        f"{FASTER_URL}/transcribe",
        headers={"Authorization": f"Bearer {FASTER_TOKEN}"},
        files={"upload_file": f},
        data={"language": "pl"},
        verify=False,
        timeout=600
    )

print(r.status_code)
print(r.json())
# Out:
# /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'rundmc-whisper-faster-bento.project-public.serving.hpepcai4.demo.local'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 200
# ...

# %%
import requests

FASTER_URL = "https://rundmc-whisper-faster-bento.project-public.serving.hpepcai4.demo.local"
FASTER_TOKEN = "eyJhbGciOiJSUzI1NiIsImtpZCI6Ikh2V3o0V1BoU3dkNFY4Tk9MSk9ObHM3Wk9UU1hxWjJLR0xyb1NwMldfSjQifQ.....eVWPkG3ZIGCdO6W27egvHo1O5_7KaL5mFXIcTddFMUAI9e4ZvOq_PjukMcwUA3ZFMaeJC0zzMIRZiYiukevmB6HrjkWsiwPNPWVI_afd2mL-cgDQh9c9HxwynGiBOeUNVyoygc_QnSCklmL84oP7vNp4EFv7DAGFlX4Agci6p1XqRcsJOpOeGnsWJYEwRsQJjyVYIVKOC_iaKgAmMozb1QYAdOBSM6o4fFfS7VDoxmKgCT7JcukGpCwS-PGY8XAko1fMs5ib4zsOfUfftKpY6rnxIv2sKGJvT3F1imuLWll4NQ0wNrDjAXt6PUotWEMfEY_1zO72EyjaRAxgYCuKtg"

with open("t1.wav", "rb") as f:
    r = requests.post(
        f"{FASTER_URL}/transcribe",
        headers={"Authorization": f"Bearer {FASTER_TOKEN}"},
        files={"upload_file": f},
        data={"language": "pl", "word_timestamps": "true"},
        verify=False,
        timeout=600
    )

print(r.status_code)
print(r.json())
# Out:
# /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'rundmc-whisper-faster-bento.project-public.serving.hpepcai4.demo.local'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 200
# ...
